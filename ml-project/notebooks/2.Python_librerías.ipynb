# %% [markdown]
# <h1 align="center"><b>LIBRERÍAS PRINCIPALES EN ANALÍTICA DE DATOS</b></h1>

# %% [markdown]
# ## Librería Numpy
#
# <div style="display: flex; align-items: center;">
#
#   <!-- Columna texto -->
#   <div style="width: 50%; padding-right: 20px;">
#     <p style="text-align: justify;">
#     Es una biblioteca de Python que se utiliza para trabajar con arreglos multidimensionales y realizar operaciones matemáticas de manera eficiente. Proporciona una amplia gama de funciones para manipular y operar con estos arreglos, lo que la convierte en una herramienta fundamental para el análisis de datos, la ciencia de datos y la computación científica.
#      </p>
#   </div>
#
#   <!-- Columna imagen -->
#   <div style="width: 50%; text-align: center;">
#     <img src="img/numpy.png" width="400" height="200">
#   </div>
#
# </div>

# %%
# Carga de librería numpy #
import numpy as np

# %%
# Creación de un vector a partir de una lista #
lista = [25, 12, 15, 66, 12.5]
vector = np.array(lista)
print(lista)
print(vector)
print(3*vector)

# %%
# Operaciones con listas #
lista = [25, 12, 15, 66, 12.5]
print(lista*3)
type(lista)

# %%
# Dimensiones de un vector #
lista = [25, 12, 15, 66, 12.5]
vector = np.array(lista)
vector.shape

# %%
 # Longitud de un vector #
len(vector)

# %%
# Diferecia entre lista y vector #
print(lista*5)
print(vector*5)

# %%
# Indexación de un vector #
lista = [25, 12, 15, 66, 12.5]
lista[1]

# %%
# Indexación de un vector #
vector = np.array(lista)
vector[0]

# %%
# Aparece un error porque el índice 5 no existe en la lista #
a=[1,2,3,4,5]
for i in a:
    print(a[i])

# %%
# Tuplas () Inmutables #
# Las tuplas son inmutables, lo que significa que no se pueden modificar después de su creación. 
# No se pueden agregar, eliminar o cambiar elementos en una tupla. 
# Por otro lado, las listas son mutables, lo que permite modificar su contenido después de su creación.
words = ("spam", "eggs", "sausages")
words[1]="salsa"

# %%
# Diccionarios {} #
# Claves y valores de las claves
ages = {"Dave":24, "Mary":42, "Jhon":52}
print(ages["Dave"])
print(ages["Mary"])

# %%
cars_colors = {"BMW": "Blue",  "VOLVO" : "Red"}
print(cars_colors["VOLVO"])

# %%
primary = {
    "red" : [255,0,0],
    "green" : [0,255,0],
    "blue" : [0,0,255],
}

print(primary["red"])
print(primary["yellow"])

# %%
test = {}
print(test[0])

# %%
squares = {1:1, 2:4, 3:"error", 4:16}
squares[8]=64
squares[5]="Hi!"
squares[3]=9
print(squares)

# %%
nums = {
    1:"one",
    2:"two",
    3:"three",
}

print(1 in nums)
print(4 not in nums)
print(5 in nums)

# %% [markdown]
# ### Operaciones con listas

# %%
lista = [25, 12, 15, 66, 12.5]
vector = np.array(lista)
print("- vector original")
print(vector)

# %%
print("- suma de los elementos:")
print(np.sum(vector))

# %%
print("- promedio (media) de los elementos:")
print(np.mean(vector)) #

# %%
print("- el vector sumado a si mismo:")
print(vector+vector)
print("- suma de vectores vector1 y vector2 (mismo tamaño):")
vector2=np.array([11,55,1.2,7.4,-8])
print(vector+vector2)

# %% [markdown]
# ### Índices y Slices

# %%
square = [0,1,4,9,16,25,36,49,64,81]
print(square[::2])
print(square[2:8:3])
print(square[-1])

# %%
# Matrices #
lista_de_listas = [ [1,-4],
                    [12, 3],
                    [7.2, 5] ]

matriz = np.array(lista_de_listas)
print(matriz)
type(lista_de_listas)
type(matriz)

# %%
# Índices y Slices #
A=np.array([[1,4], [-2,6], [10,4]])

# %%
# Producto Hadamard
a = np.array([[1,2],[3,4]])
b = np.array([[5,6],[7,8]])
np.multiply(a,b)

# %% [markdown]
# ## Librería Pandas
#
# <p align="center">
#   <img src="img/pandas.png" width="750" height="400">
# </p>
#
# Pandas es una biblioteca de Python que se utiliza para la manipulación y análisis de datos. Proporciona estructuras de datos flexibles y potentes, como DataFrames, que permiten trabajar con datos tabulares de manera eficiente. Pandas ofrece una amplia gama de funciones para limpiar, transformar, analizar y visualizar datos, lo que la convierte en una herramienta esencial para el análisis de datos en Python.

# %% [markdown]
# ## Funciones de lectura
#
# Las funciones **read_csv**, **read_table** y **read_excel** son las más empleadas.
#
# - read_clipboard
# - read_hdf
# - read_html
# - read_json
# - read_pickle
# - read_sas
# - read_sql
# - read_stata

# %% [markdown]
# A continuación se muestra una descripción general de la mecánica de estas funciones, que están destinadas a convertir datos de texto en un DataFrame. Los argumentos opcionales para estas funciones pueden clasificarse en algunas categorías:
#
# - **Indexación**:
# Puede tratar una o más columnas como el DataFrame devuelto, y si desea obtener nombres de columna del archivo, el usuario, o no obtenerlos.
#
# - **Inferencia de tipos y conversión de datos**:
# Esto incluye las conversiones de valores definidos por el usuario y la lista personalizada de marcadores de valores faltantes.
#
# - **Análisis de fecha y hora**:
# Incluye la capacidad de combinación, incluida la combinación de información de fecha y hora distribuida en varias columnas en una sola columna en el resultado.
#
# - **Iterando**:
# Soporte para iterar sobre fragmentos de archivos muy grandes.
#
# - **Problemas de datos sucios**:
# Saltar filas o un pie de página, comentarios u otras cosas menores como datos numéricos con miles separados por comas.
#
# ---

# %% [markdown]
# ## 1. Lectura de datos de un archivo .json
#
# <div style="display: flex; align-items: center;">
#
#   <!-- Columna texto -->
#   <div style="width: 50%; padding-right: 20px;">
#     <p style="text-align: justify;">
#       JSON (JavaScript Object Notation) es un formato de texto utilizado para almacenar e intercambiar datos de forma estructurada.
# Está organizado en forma de:
#
# - Pares -> clave : valor
#
# - Similar a un diccionario en Python
#
# Es útil para intercambiar datos entre sistemas:
#
# Por ejemplo:
#
# - Python ↔ Web
# - Python ↔ API
# - Python ↔ Base de datos
#
# Iniciemos con el uso de la función read_json, en el siguiente ejemplo se busca obtener los siguientes Datos formato .json en un formato Data.Frame de pandas almacenado en un objeto llamado df.
#      </p>
#   </div>
#
#   <!-- Columna imagen -->
#   <div style="width: 50%; text-align: center;">
#     <img src="img/json.jpg" width="400" height="300">
#   </div>
#
# </div>

# %%
import pandas as pd
import numpy as np
import io # Para manejar datos en memoria como si fueran archivos
import json # Para trabajar con datos en formato JSON, que es común en la web y en APIs
import requests # Conectarte a internet desde Python y descargar información de páginas web o APIs, especialmente cuando se usa entornos virtuales

# %% [markdown]
# ### **Ejemplo :** Lectura de un archivo .json desde una URL

# %% [markdown]
# ### Descripción de los datos
#
# Esta base de datos contiene registros administrativos públicos del Condado de San Mateo en formato JSON. Cada fila representa un registro individual y cada columna una variable. Es utilizada para análisis de datos, visualización y prácticas de ciencia de datos con Python y Pandas.
#
# | Columna                                | Significado                                                                                                                |
# | -------------------------------------- | -------------------------------------------------------------------------------------------------------------------------- |
# | **geography**                          | Nombre de la zona geográfica (por ejemplo, ciudad, condado o región).                                                      |
# | **geography_type**                     | Tipo de área geográfica (por ejemplo: ciudad, condado, estado, etc.).                                                      |
# | **year**                               | Año al que corresponden los datos.                                                                                         |
# | **less_than_high_school_graduate**     | Número o porcentaje de personas cuyo nivel educativo es menor que secundaria completa.                                     |
# | **high_school_graduate**               | Número o porcentaje de personas que completaron la secundaria.                                                             |
# | **some_college_or_associate_s_degree** | Número o porcentaje de personas que estudiaron algo de universidad o tienen título técnico/tecnológico (Associate degree). |
# | **bachelor_s_degree_or_higher**        | Número o porcentaje de personas con título universitario profesional o superior (maestría, doctorado, etc.).               |
# | **location_1**                         | Coordenadas geográficas (latitud y longitud) de la zona.                                                                   |
# | **:@computed_region_uph5_8hpn**        | Código interno generado automáticamente para identificar una región (uso técnico del sistema).                             |
# | **:@computed_region_i2t2_cryp**        | Otro código interno de clasificación geográfica usado por la plataforma de datos.                                          |

# %%
# Lectura de un archivo .json desde una URL #
url = "https://datahub.smcgov.org/id/mb6a-xn89.json"
response = requests.get(url) # Python va a esa dirección y descarga los datos
df_js = pd.read_json(io.StringIO(response.text)) # Convierte el texto JSON en un DataFrame de Pandas

# %%
# Método que muestra las primeras filas del DataFrame #
df_js.head()

# %%
# Método que muestra las últimas filas del DataFrame #
df_js.tail()

# %%
# Información general del DataFrame #
df_js.info()

# %%
# Dimensiones del DataFrame #
df_js.shape

# %%
# Descripción de los datos #
df_js.describe()

# %%
# Tipos de datos de cada columna #
df_js.dtypes

# %%
# Descripción de las columnas geografía, tipo de geografía y año #
df_js[["geography", "geography_type", "year"]].describe()

# %%
# Listado de las columnas del DataFrame #
df_js.columns.tolist()

# %%
# Descripción de los datos sin la columna location_1 #
df_js.drop("location_1", axis=1).describe(include="all")

# %%
# Renombrar la variable de salida #
df_js.rename(columns={':@computed_region_uph5_8hpn': 'region_automatic'}, inplace=True)
df_js.info()

# %%
# Renombrar la variable de salida #
df_js.rename(columns={'geography': 'geog', 'geography_type': 'geog_type'}, inplace=True)
df_js.info()

# %% [markdown]
# ---
# ## 2. Lectura de datos de un archivo .csv
#
# <div style="display: flex; align-items: center;">
#
#   <!-- Columna texto -->
#   <div style="width: 50%; padding-right: 20px;">
#     <p style="text-align: justify;">
#     CSV (Comma-Separated Values) es un formato de archivo de texto que se utiliza para almacenar datos tabulares, donde cada línea del archivo representa una fila de la tabla y los valores dentro de cada fila están separados por comas. Es un formato comúnmente utilizado para intercambiar datos entre diferentes programas y plataformas debido a su simplicidad y compatibilidad.
#      </p>
#   </div>
#
#   <!-- Columna imagen -->
#   <div style="width: 50%; text-align: center;">
#     <img src="img/csv.png" width="250" height="250">
#   </div>
#
# </div>
#
# ---

# %% [markdown]
# ### Descripción de los datos
#
# La base de datos Promos.csv contiene información sobre campañas de marketing telefónico realizadas por una institución financiera, cuyo objetivo es determinar si un cliente acepta o no una promoción de depósito a término.
#
# Cada fila representa:
#
# 👉 un cliente contactado en una campaña
#
# Cada columna representa:
#
# 👉 características del cliente, la campaña y el contexto económico
#
# | Variable       | Descripción                                                   |
# | -------------- | ------------------------------------------------------------- |
# | age            | Edad del cliente                                              |
# | job            | Tipo de trabajo                                               |
# | marital        | Estado civil                                                  |
# | education      | Nivel educativo                                               |
# | default        | Tiene crédito en incumplimiento                               |
# | credit         | Tiene crédito hipotecario                                     |
# | prestamo       | Tiene préstamo personal                                       |
# | contact        | Tipo de contacto (celular o teléfono fijo)                    |
# | month          | Mes de contacto                                               |
# | day_of_week    | Día de la semana del contacto                                 |
# | duration       | Duración de la llamada (segundos)                             |
# | campaign       | Número de contactos realizados en la campaña                  |
# | pdays          | Días desde el último contacto previo (999 = nunca contactado) |
# | previous       | Número de contactos previos                                   |
# | poutcome       | Resultado de la campaña anterior                              |
# | emp.var.rate   | Tasa de variación del empleo                                  |
# | cons.price.idx | Índice de precios al consumidor                               |
# | cons.conf.idx  | Índice de confianza del consumidor                            |
# | r              | Tasa de interés                                               |
# | nr.employed    | Número de empleados                                           |
# | y              | Variable objetivo: aceptó la promoción (yes/no)               |

# %%
# Librerías para el manejo de datos #
import os             # Interactúa con el sistema operativo (archivos, rutas)
import numpy as np    # Cálculo numérico con arrays
import pandas as pd   # Manipulación y análisis de datos
import io             # Manejo de flujos en memoria

# %% [markdown]
# ### Funciones para tratar Data Frame
#
# | **Función** | **Descripción** |
# |--------|------------|
# |  |  |
# | `df.head()` | Primeras filas |
# | `df.tail()` | Últimas filas |
# | `df.sample(5)` | Muestra aleatoria |
# | `df.info()` | Info general del DataFrame |
# | `df.describe()` | Estadísticas descriptivas |
# | `df.shape` | Dimensión (filas, columnas) |
# | `df.columns` | Nombres de columnas |
# |  |  |
# | `df["col"]` | Seleccionar una columna |
# | `df[["col1","col2"]]` | Seleccionar múltiples columnas |
# | `df.loc[filas, columnas]` | Selección por etiquetas |
# | `df.iloc[filas, columnas]` | Selección por posición |
# | `df[df["edad"] > 30]` | Filtrar filas |
# |  |  |
# | `df.isnull()` | Detectar valores nulos |
# | `df.dropna()` | Eliminar nulos |
# | `df.fillna(0)` | Rellenar nulos |
# | `df.drop_duplicates()` | Eliminar duplicados |
# | `df.rename(columns={"old":"new"})` | Renombrar columnas |
# | `df.astype(float)` | Cambiar tipo de dato |
# |  |  |
# | `df["nueva"] = df["x"] * 2` | Crear nueva columna |
# | `df.apply(func, axis=1)` | Aplicar función por fila |
# | `df.map(func)` | Aplicar función (Series) |
# | `df.replace()` | Reemplazar valores |
# |  |  |
# | `df.groupby("grupo").mean()` | Promedio por grupo |
# | `df.groupby("grupo").agg({"col":"sum"})` | Agregación personalizada |
# | `df.value_counts()` | Conteo de valores |
# |  |  |
# | `df.sort_values("col")` | Ordenar por columna |
# | `df.sort_index()` | Ordenar por índice |
# |  |  |
# | `pd.concat([df1, df2])` | Concatenar DataFrames |
# | `pd.merge(df1, df2, on="id")` | Unir por clave |
# |  |  |
# | `pd.read_csv("file.csv")` | Leer CSV |
# | `df.to_csv("file.csv")` | Guardar CSV |
# | `pd.read_excel("file.xlsx")` | Leer Excel |
# | `df.to_excel("file.xlsx")` | Guardar Excel |
# |  |  |
# | `pd.to_datetime(df["fecha"])` | Convertir a fecha |
# | `df.set_index("fecha")` | Indexar por fecha |
# | `df.resample("M").mean()` | Agregar por periodo |

# %%
# Organizar las rutas de acceso a los datos #
mainpath= "/Users/duvancatano/Documents/Data_Analytics_UdeA/ml-project/data/promotions" #Cuando aparece "\" coloco r adelante
filename= "promos.csv"
fullpath= os.path.join(mainpath,filename)

# %%
# Cargar los datos #
data = pd.read_csv(fullpath, sep=";")      # El separador es ";" porque en el archivo .csv los valores están separados por punto y coma
pd.set_option('display.max_columns', None) # Para mostrar todas las columnas del DataFrame sin truncar
data.head()

# %%
# Lista de las columnas del DataFrame #
data.columns.tolist()

# %%
# Valores únicos de la variable educación #
data["education"].unique().tolist()

# %%
# Homogenizar la variable educación basic.4y, basic.6y, basic.9y, university.degree = Basic # 
data["education"] = np.where(data["education"]=="basic.4y", "Basic", data["education"])
data["education"] = np.where(data["education"]=="basic.6y", "Basic", data["education"])
data["education"] = np.where(data["education"]=="basic.9y", "Basic", data["education"])

# Poner letra inicial en mayuscula high.school=High School, professional.course=Professional Course, university.degree=University Degree
data["education"] = np.where(data["education"]=="high.school", "High School", data["education"])
data["education"] = np.where(data["education"]=="professional.course", "Professional Course", data["education"])
data["education"] = np.where(data["education"]=="university.degree", "University Degree", data["education"])

# Poner letra inicial en mayuscula illiterate=Illiterate, unknown=Unknown
data["education"] = np.where(data["education"]=="illiterate", "Illiterate", data["education"])
data["education"] = np.where(data["education"]=="unknown", "Unknown", data["education"])

# %%
# Comprobar la Homogenización de la variable educación #
data["education"].unique().tolist()

# %%
# Comprobar la Homogenización de la variable educación #
data["y"].unique().tolist()

# %%
# Obtener la media de cada una de las variables según los tipos de clientes 
data.groupby("y").mean(numeric_only=True)

# %% [markdown]
# ### 1. Importar Librerías

# %%
# Manipulación
import pandas as pd
import numpy as np

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración estética
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (8,5)

# Mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 2. Información General

# %%
# Dimensiones del DataFrame #
data.shape

# %%
# Información general del DataFrame #
data.info()

# %%
# Descripción de los datos #
data.describe()

# %%
# Descripción de los datos con las variables categóricas #
data.describe(include = "object")

# %%
# Valores nulos por columna #
data.isnull().sum()

# %%
# Porcentaje de valores nulos por columna #
(data.isnull().sum()/len(data))*100

# %% [markdown]
# ### 3. Distribución de Variables Numéricas

# %%
# Distribución de variables numéricas # 
data.hist(bins=30, figsize=(12,10))
plt.show()

# %% [markdown]
# ### 4. Gráficos de Densidad

# %%
data.plot(kind='density', subplots=True, layout=(4,3), figsize=(12,10))
plt.show()

# %% [markdown]
# ### 5. Boxplot (Detección de Outliers)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=data[["age", "duration", "nr.employed"]]) # Solo seleccionamos las columnas numéricas para el boxplot
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 6. Conteo de Variable Objetivo

# %%
sns.countplot(x="y", data=data)
plt.title("Distribución variable objetivo")
plt.show()

# %% [markdown]
# ### 7. Relación Entre Variables Categóricas y Objetivo

# %%
sns.countplot(x="job", hue="y", data=data)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 8. Tablas de Contingencia

# %%
pd.crosstab(data["job"], data["y"])

# %% [markdown]
# ### 9. Relación Variable Numérica vs Objetivo

# %%
sns.boxplot(x="y", y="age", data=data)
plt.show()

# %% [markdown]
# ### 10. Matriz de Correlación

# %%
# Seleccionamos solo las columnas numéricas para la matriz de correlación #
data_num = data.select_dtypes(include=np.number)

# %%
# Matriz de correlación #
corr = data_num.corr()
corr

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ### 11. Pairplot (Relaciones Múltiples)

# %%
sns.pairplot(data_num)
plt.show()

# %% [markdown]
# ### 12. Gráfico de Dispersión

# %%
# Gráfico de dispersión con dos variables numéricas #
sns.scatterplot(x="age", y="duration", data=data)
plt.show()

# %%
# Gráfico de dispersión con color según la variable objetivo #
sns.scatterplot(x="age", y="duration", hue="y", data=data)
plt.show()

# %% [markdown]
# ### 13. Distribución por Grupos

# %%
#sns.violinplot(x="y", y="age", data=data) # Respuesta con respeto a la edad  
sns.violinplot(x="y", y="duration", data=data) # Respuesta con respeto a la duración de la llamada
plt.show()

# %% [markdown]
# ### 14. Media por Grupo

# %%
data.groupby("y")["duration"].mean()

# %% [markdown]
# ### 15. Tabla Resumen Completa

# %%
data.groupby("y").describe()

# %% [markdown]
# ### 16. Conteo Variables Categóricas

# %%
data["job"].value_counts()

# %%
# Gráfico de barras para la variable job #
data["job"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# ### 17. Proporciones

# %%
# Analizar el Desbalanceo #
data["y"].value_counts(normalize=True)

# %% [markdown]
# ### 📊 18. Análisis Conjunto Completo

# %%
sns.catplot(x="job", hue="y", kind="count", data=data, height=6, aspect=2)
plt.show()

# %% [markdown]
# ### 19. Variables Numéricas por Objetivo

# %%
data.groupby("y")[data_num.columns].mean()

# %% [markdown]
# ### 20. Distribución Conjunta Avanzada

# %%
sns.jointplot(x="age", y="duration", data=data, kind="scatter")
plt.show()

# %% [markdown]
# ### 21. Outliers Individuales

# %%
sns.boxplot(x=data["duration"])
plt.show()

# %% [markdown]
# ### 24. Exportar Resumen

# %%
data.describe().to_csv("Resumen_estadistico.csv")

# %% [markdown]
# ---
# <div style="display: flex; align-items: center;">
#
# <!-- Columna imagen -->
#   <div style="width: 50%; text-align: center;">
#     <img src="img/str.png" width="250" height="130">
#   </div>
#
#   <!-- Columna texto -->
#   <div style="width: 50%; padding-right: 20px;">
#     <p style="text-align: justify;">
#     Streamlit es un framework de Python que permite convertir scripts en aplicaciones web interactivas de forma rápida, sin necesidad de saber desarrollo web (HTML, CSS o JavaScript).
#
#     Python → Dashboard web en minutos
#   </div>
#
# </div>
#
# ---
#
#
# ### **¿Para qué sirve?**
#
# 📊 Dashboards interactivos
#
# 📈 Visualizaciones dinámicas
#
# 🤖 Interfaces para modelos de Machine Learning
#
# 🧪 Herramientas de análisis exploratorio (EDA)
#
# 📉 Aplicaciones para toma de decisiones
#
# 🚀 Alcances
#
# - Construcción rápida de apps
#
# - Integración directa con librerías como Pandas, Plotly, Scikit-learn
#
# - Interactividad en tiempo real (filtros, sliders, inputs)
#
# - Despliegue sencillo (Streamlit Cloud, Render)
#
# - Soporte para múltiples páginas (apps complejas)
#
# ---
#
# ## **Utilidades en Ciencia de Datos**
#
# - Mostrar resultados a clientes o stakeholders
#
# - Convertir modelos en aplicaciones utilizables
#
# - Automatizar reportes interactivos
#
# - Visualización en vivo
#
# - Crear portafolio profesional
#
# ---

# %% [markdown]
# ## **Ejecución**
#
# ---
#
# **Ejecutar en la terminal**
#
# ```pip install streamlit pandas numpy matplotlib seaborn plotly```
#
# ---
#
# **Verificar la Instalación**
#
# ```pip list```
#
# ---
#
# **Ejecución desde la Terminal parado en src**
#
# ```streamlit run app.py```
#
# ---
#
# # 🎬 **¡FIN!**
#
# ---
#
# <div style="text-align: justify; line-height: 1.5; font-size: 18px;">    </div>
