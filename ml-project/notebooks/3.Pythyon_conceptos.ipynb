# %% [markdown]
# ---
# <div align="center">
#
# # **ANÁLISIS EXPLORATORIO DE DATOS (EDA)**
#
# </div>
#
# ---
#
# <div style="display: flex; align-items: center;">
#
#   <!-- Columna texto -->
#   <div style="width: 50%; padding-right: 20px;">
#     <p style="text-align: justify;">
#       El análisis exploratorio de datos (EDA) es un enfoque para analizar conjuntos de datos con el objetivo de resumir sus características  principales, a menudo utilizando métodos visuales para responder <strong style="color:#d62728;">Preguntas de Interés</strong>. El EDA es una etapa crucial en el proceso de análisis de datos, ya que permite a los analistas comprender mejor la estructura, las relaciones y las tendencias presentes en los datos antes de aplicar modelos estadísticos o de machine learning.
#      </p>
#   </div>
#
#   <!-- Columna imagen -->
#   <div style="width: 50%; text-align: center;">
#     <img src="img/norris.png" width="300" height="200">
#   </div>
#
# </div>

# %% [markdown]
# ---
# ## **Con el EDA se busca:**
#
# 1. Comprender los datos y el problema.
#
# 2. Generar y validar hipótesis.
#
# 3. Identificar patrones, relaciones y anomalías.
#
# 4. Evaluar la calidad de los datos y prepararlos.
#
# 5. Apoyar la toma de decisiones y la selección de modelos.

# %% [markdown]
# <p align="center">
#   <img src="img/EDA.png" width="750" height="500">
# </p>
#
# ---

# %% [markdown]
# ## **Proceso Metodológico del Análisis Exploratorio de Datos**
#
# <!--1. **Definir el problema y las preguntas de interés**: Antes de comenzar el análisis, es fundamental tener claro el objetivo del análisis y las preguntas específicas que se desean responder con los datos.
#
# 2. **Recolección de datos**: Obtener los datos necesarios para el análisis, ya sea a través de fuentes internas, externas o mediante la recopilación directa.
#
# 3. **Limpieza y preparación de datos**: Revisar los datos para identificar y corregir errores, manejar valores faltantes, eliminar duplicados y transformar los datos según sea necesario para facilitar el análisis.
#
# 4. **Análisis univariado**: Examinar cada variable individualmente para entender su distribución, tendencia central, dispersión, presencia de valores atípicos y evolución temporal.
#
# 5. **Análisis multivariado**: Analizar las relaciones entre múltiples variables simultáneamente, utilizando técnicas como análisis de correlación, análisis de componentes principales, entre otros.
#
# 6. **Visualización de datos**: Crear gráficos y visualizaciones para representar los datos de manera clara y efectiva, facilitando la interpretación de los resultados.
#
# 7. **Evaluación de resultados y generación de conclusiones**: Interpretar los hallazgos del análisis, responder a las preguntas de interés y generar conclusiones basadas en los datos.
#
# 8. **Clustering y segmentación**: Identificar grupos o segmentos dentro de los datos que compartan características similares, lo que puede ser útil para la toma de decisiones y la personalización de estrategias.
#
# 9. **Selección de características**: Identificar las variables más relevantes para el análisis o para la construcción de modelos predictivos, lo que puede mejorar la eficiencia y la precisión del análisis.
#
# 10. **Ingeniería de características**: Crear nuevas variables a partir de las existentes para capturar mejor la información y mejorar el rendimiento de los modelos predictivos.-->
#
# <div align="center">
#
# | ETAPA | DESCRIPCIÓN |
# |------|------------|
# | **Definir el problema** | Establecer el objetivo del análisis y las preguntas a responder. |
# | **Recolección de datos** | Obtener los datos desde fuentes internas, externas o recopilación directa. |
# | **Limpieza y preparación** | Corregir errores, tratar valores faltantes y transformar datos. |
# | **Análisis univariado** | Estudiar cada variable: distribución, tendencia y outliers. |
# | **Análisis multivariado** | Analizar relaciones entre variables (correlación, PCA, etc.). |
# | **Visualización** | Representar los datos mediante gráficos claros e interpretables. |
# | **Evaluación y conclusiones** | Interpretar resultados y responder las preguntas planteadas. |
# | **Clustering** | Identificar grupos o segmentos con características similares. |
# | **Selección de características** | Elegir variables relevantes para el análisis o modelado. |
# | **Ingeniería de características** | Crear nuevas variables para mejorar el análisis o modelos. |
#
# </div>

# %% [markdown]
# ---
# ## **Análisis Exploratorio Cuantitativo de Datos:**
# ---
#
# En el análisis exploratorio de datos se busca obtener información de interés  de la población a partir de una muestra representativa. Para esto se pueden utilizar técnicas de muestreo, como el muestreo aleatorio simple, el muestreo estratificado o el muestreo por conglomerados, entre otros. Estas técnicas permiten seleccionar una muestra que sea representativa de la población, lo que a su vez permite obtener conclusiones válidas y generalizables sobre la población a partir del análisis de la muestra.
#
# <div align="center">
#
# | ETAPA | DESCRIPCIÓN |
# |------|------------|
# |**Ubicación del centro de los datos** | Media, mediana, moda, percentiles|
# |**Dispersión de los datos** | Rango, varianza, desviación estándar, coeficiente de variación|
# |**Distribución de los datos** | Histograma, densidad, asimetría, curtosis|
# |**Relaciones entre variables** | Correlación, covarianza, análisis de regresión|
# |**Identificación de valores atípicos** | Boxplot, z-score|
# |**Análisis de tendencias y patrones** | Gráficos de líneas, gráficos de dispersión|
#
# </div>

# %% [markdown]
# ---
# ## **Objetivos:**
# ---
# Uno de los objetivos fundamentales en estadística es obtener información de interés sobre una población a partir de una muestra representativa.
# Para lograr esto, se utilizan técnicas de muestreo que permiten seleccionar una muestra que sea representativa de la población, lo que a su vez permite obtener conclusiones válidas y generalizables sobre la población a partir del análisis de la muestra. En el análisis exploratorio cuantitativo de datos, se busca identificar patrones, tendencias y relaciones entre variables utilizando técnicas estadísticas y visualizaciones para comprender mejor los datos y generar hipótesis para análisis posteriores.

# %% [markdown]
# <p align="center">
#   <img src="img/muestreo.png" width="750" height="500">
# </p>

# %% [markdown]
# ---
# ## **Conceptos Clave:**
#
# - **Población**: Conjunto completo de individuos, objetos o eventos que comparten una característica común y sobre los cuales se desea obtener información.
#
# - **Parámetro**: Medida numérica que describe una característica de la población, como la media poblacional o la proporción poblacional.
# - **Muestra**: Subconjunto representativo de la población que se selecciona para su análisis, con el objetivo de inferir información sobre la población.
#
# - **Estadístico**: Medida numérica que describe una característica de la muestra, como la media muestral o la proporción muestral.
#
# - **Muestreo**: Proceso de seleccionar una muestra representativa de la población, utilizando técnicas como el muestreo aleatorio simple, el muestreo estratificado o el muestreo por conglomerados, entre otros.
#
# ---
#
# ### **Tipo de Datos:**
# - **Datos Categóricos**: Variables que representan categorías o grupos, como género, estado civil o tipo de vivienda.
#
# - **Datos Numéricos**: Variables que representan cantidades o medidas, como ingresos, edad o precio de la vivienda.
#
# - **Datos Ordinales**: Variables que representan categorías con un orden o jerarquía, como nivel educativo (primaria, secundaria, universidad)  o nivel de satisfacción (bajo, medio, alto).
#
# - **Datos de Tiempo**: Variables que representan momentos o períodos de tiempo, como fecha de nacimiento, fecha de compra o fecha de registro.
#
# ---
#
# ### **Datos Rectangulares:**
#
# - **Datos Estructurados**: Datos organizados en un formato tabular, con filas y columnas, donde cada columna representa una variable y cada fila representa una observación o registro.
#
# - **Datos No Estructurados**: Datos que no siguen un formato tabular, como texto, imágenes, audio o video, y que requieren técnicas de procesamiento específicas para su análisis.
#
# - **Features**: Características o atributos de los datos que se utilizan para realizar el análisis o el modelado.
#
# - **Target**: Variable objetivo o variable dependiente que se desea predecir o explicar a partir de las features.
#
# - **Outcome**: Variable que se desea predecir o explicar en un problema de modelado.
#
# - **Registro**: Cada fila en un conjunto de datos estructurados, que representa una observación individual o una entidad específica.

# %% [markdown]
# <p align="center">
#   <img src="img/conceptos.png" width="750" height="500">
# </p>

# %% [markdown]
# ---
# # **Dependencia Entre Variables**
# ---
#
# ### Definición
#
# La dependencia entre variables describe cómo el valor de una variable se relaciona con el valor de otra. En particular, al estudiar la dependencia entre una variable **continua** y una **categórica** buscamos entender si los grupos definidos por la variable categórica tienen valores distintos (y en qué medida) en la variable continua.
#
# - **Variable continua**: toma valores numéricos en un rango (ej. ingresos, edad, temperatura).
#
# - **Variable categórica**: toma valores discretos que representan categorías o clases (ej. género, región, tipo de producto).
#
# ---
#
# ### ¿Por qué estudiar la dependencia entre variables continuas y categóricas?
#
# 1. **Comprender patrones**: Saber si la variable continua varía según la categoría (por ejemplo, ingresos por región) ayuda a identificar diferencias relevantes.
#
# 2. **Selección de variables**: Identificar variables que aportan información predictiva para modelos supervisados.
#
# 3. **Formular hipótesis**: Permite plantear y validar hipótesis (por ejemplo, "¿los clientes de un segmento gastan más?").
#
# 4. **Tomar decisiones**: Influye en estrategias de negocio o políticas basadas en segmentación de grupos.
#
# 5. **Validar suposiciones**: Muchos modelos requieren independencia entre variables o una relación específica.
#
# ---
#
# ### Métodos comunes para analizar la dependencia
#
# - Comparar estadísticas de resumen (media, mediana, desviación) de la variable continua por categoría.
#
# - Visualizaciones: boxplots, violin plots, gráficos de barras con barras de error.
#
# - Pruebas estadísticas: ANOVA, t-test para diferencias de medias; chi-cuadrado si se discretiza la continua; regresión lineal con variables dummy.
# ---

# %% [markdown]
# ## Objetivo
#
# Evaluar dependencia según el tipo de variables:
#
# - Continuas
#
# - Categóricas
#
# - Mixtas (continua vs categórica)
#
# ---
# ---

# %% [markdown]
# # 1. Variables Continuas
#
# ## Correlación
#
# ### Definición
#
# La correlación mide el grado de asociación lineal entre dos variables cuantitativas:
#
#
# $$\rho = \frac{Cov(X,Y)}{\sigma_X \sigma_Y}$$
#
# ---
#
# ### Interpretación
#
# - $ρ ≈ 1 →$ relación positiva fuerte
# - $ρ ≈ -1 →$ relación negativa fuerte
# - $ρ ≈ 0 →$ no hay relación lineal
#
# ---
#
# ###  Importante
#
# - Correlación $≠$ causalidad
# - Pearson mide relación lineal
# - Spearman mide relación monótona (más general)

# %% [markdown]
# ---
# ---
# ## Prueba de Pearson (Correlación Lineal)
#
# 🧠 Hipótesis
#
# - $H_0 : \rho = 0$ (No hay Correlación Lineal)
#
# - $H_a : \rho \neq 0$ (Hay Correlación Lineal)

# %% [markdown]
# ---
# ---
# ## Spearman (Correlación Monótona)
#
# 🧠 Hipótesis
#
# - $H_0 : \rho = 0$ (No hay Relación Monótona)
#
# - $H_a : \rho \neq 0$ (Hay Relación Monótona)
# ---
# ---

# %% [markdown]
# <p align="center">
#   <img src="img/corr.png" width="900" height="500">
# </p>

# %% [markdown]
# ---
# ---

# %%
# Carga de Librerías #
import numpy as np               # Computación numérica (arrays, álgebra, operaciones rápidas) 
import pandas as pd              # Manipulación y análisis de datos (DataFrames)
import seaborn as sns            # Visualización estadística de alto nivel
import matplotlib.pyplot as plt  # Gráficas básicas y personalización
from scipy import stats          # Pruebas estadísticas y distribuciones
import os                        # Interacción con el sistema operativo (archivos, rutas, carpetas)

# %% [markdown]
# ## Relaciones Lineales

# %%
# Geberación de Datos (Tenmdencia Lineal)# 
np.random.seed(42)
x = np.random.normal(0, 1, 100)
y = -2*x + np.random.normal(0, 1, 100)

# %%
# Gráfico de Dispersión # 
sns.regplot(x=x, y=y)

plt.title("Relación entre x e y con tendencia")
plt.xlabel("Variable X")
plt.ylabel("Variable Y")

plt.show()

# %%
# Prueba de Pearson #
corr, p_value = stats.pearsonr(x, y)

print(f"Correlación de Pearson: {corr:.4f}")
print(f"p-value: {p_value:.6f}")

# Interpretación automática
alpha = 0.05
if p_value < alpha:
    print("Se rechaza H0: Existe relación lineal")
else:
    print("No se rechaza H0: No hay evidencia de relación lineal")

# %%
# Prueba de Spearman #
corr, p_value = stats.spearmanr(x, y)

print(f"Correlación de Spearman: {corr:.4f}")
print(f"p-value: {p_value:.6f}")

# Interpretación automática
alpha = 0.05
if p_value < alpha:
    print("Se rechaza H0: Existe relación monótona")
else:
    print("No se rechaza H0: No hay evidencia de relación monótona")

# %% [markdown]
# ## Relaciones No Lineales

# %%
# Generación de los Datos #
np.random.seed(42)

# Más datos (clave)
x = np.linspace(1, 100, 200)

# Relación NO lineal pero monótona (exponencial suave)
y = np.log(x) + np.random.normal(0, 0.1, 200)

# %%
# Gráfica #
sns.scatterplot(x=x, y=y)
plt.title("Relación Monótona No Lineal")
plt.show()

# %%
# Función que realiza las pruebas de Pearsin y Spearman #

from scipy import stats

def pruebas_correlacion(x, y, alpha=0.05):
    
    # Pearson #
    corr_p, p_p = stats.pearsonr(x, y)
    
    # Spearman #
    corr_s, p_s = stats.spearmanr(x, y)
    
    print(" Resultados")
    print("")
    
    print("🔹 Pearson (Relación Lineal)")
    print(f"Correlación: {corr_p:.4f}")
    print(f"p-value: {p_p:.6f}")
    
    if p_p < alpha:
        print("→ Se rechaza H0: Existe relación lineal\n")
    else:
        print("→ No se rechaza H0: No hay evidencia de relación lineal\n")
    
    print("🔹 Spearman (Relación Monótona)")
    print(f"Correlación: {corr_s:.4f}")
    print(f"p-value: {p_s:.6f}")
    
    if p_s < alpha:
        print("→ Se rechaza H0: Existe Relación Monótona\n")
    else:
        print("→ No se rechaza H0: No hay evidencia de Relación Monótona\n")

# %%
# Función que ejecuta las Pruebas Conjuntas #
pruebas_correlacion(x,y)

# %%
# Organizar Rutas "os" #
mainpath= "/Users/duvancatano/Documents/Data_Analytics_UdeA/ml-project/data/housing"
filename= "housing_dataset.csv"
fullpath= os.path.join(mainpath,filename)

# %%
# Cargar Datos #
data = pd.read_csv(fullpath, sep=",") # El separador es "," porque en el archivo .csv los valores están separados por coma
pd.set_option('display.max_columns', None) # Para mostrar todas las columnas del DataFrame sin truncar
data.head(10)

# %%
# Campos en una Columna #
data.columns.tolist()

# %%
# Gráfico de Dispersión #
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    x=data["area_total_m2"],
    y=data["valor_de_mercado_de_la_vivienda"]
)

sns.regplot(
    x=data["area_total_m2"],
    y=data["valor_de_mercado_de_la_vivienda"],
    scatter=False,      # solo la línea
    color="red",
    ci=99              # intervalo de confianza al 95%
)

plt.title("Relación del Área de la Vivienda con el Valor del Mercado")
plt.show()

# %%
# Función que ejecuta ambas pruebas #
pruebas_correlacion(data["valor_de_mercado_de_la_vivienda"], data["area_total_m2"])

# %% [markdown]
# ---

# %% [markdown]
# # Prueba de Kendall
#
# ## Definición
#
# La prueba de Kendall (o Kendall’s Tau) es una medida no paramétrica que evalúa la fuerza y dirección de la relación monótona entre dos variables continuas u ordinales.
#
# Se basa en comparar pares de observaciones:
#
# 🔹 Pares concordantes: cuando el orden relativo entre dos observaciones es consistente en ambas variables
# 🔹 Pares discordantes: cuando el orden se invierte
#
# La idea clave es:
#
# si la mayoría de los pares mantienen el mismo orden, hay dependencia.
#
#
# $$\tau = \frac{C-D}{(1/2)n(n-1)}$$
#
# - $C$ : número de pares concordantes
# - $D$ : número de pares discordantes
# - $n$ : número de observaciones

# %% [markdown]
# ## Interpretación
#
# - $\tau$ ≈ 1 → Relación Creciente Fuerte
#
# - $\tau$ ≈ −1 → Relación Decreciente Fuerte
#
# - $\tau$ ≈ 0 → No hay Relación
#
#
# ### ¿Qué prueba de hipótesis realiza?
#
# $H_0$ : Las variables son Independientes
#
# $H_a$ : Existe Relación Monótona

# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Relación monótona con algo de ruido
x = data["area_total_m2"]
y = data["valor_de_mercado_de_la_vivienda"]

# %%
# Gráfico de Dispersión #
sns.scatterplot(x=x, y=y)
plt.title("Relación entre x e y")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
# Función que ejecuta la prueba de Kendall #
def prueba_kendall(x, y, alpha=0.05):
    
    tau, p_value = stats.kendalltau(x, y)
    
    print("🔹 Prueba de Kendall \n")
    print(f"Tau: {tau:.4f}")
    print(f"p-value: {p_value:.6f}\n")
    
    # Decisión
    if p_value < alpha:
        print("✅ Se rechaza H0: Existe relación monótona")
    else:
        print("❌ No se rechaza H0: No hay evidencia de relación")
    
    # Interpretación de magnitud
    print("\n Interpretación :")
    
    if abs(tau) < 0.2:
        print("Relación muy débil o inexistente")
    elif abs(tau) < 0.4:
        print("Relación débil")
    elif abs(tau) < 0.6:
        print("Relación moderada")
    elif abs(tau) < 0.8:
        print("Relación fuerte")
    else:
        print("Relación muy fuerte")

# %%
# Ejecución de la Prueba de Kendall #
prueba_kendall(x, y, alpha=0.05)

# %%
# Ejecutando todas las pruebas #
pruebas_correlacion(data["valor_de_mercado_de_la_vivienda"], data["area_total_m2"])
prueba_kendall(x, y, alpha=0.05)

# %% [markdown]
# ---
# ---

# %% [markdown]
# # 2. Variables Categóricas
#
# En muchos problemas reales, los datos no son números continuos sino categorías: género, tipo de producto, respuesta sí/no, nivel educativo, entre otros. A simple vista, comparar proporciones puede parecer suficiente. Sin embargo: las diferencias observadas en los datos pueden deberse al azar y no a una relación real.
#
# Por eso usamos pruebas de hipótesis para variables categóricas, que nos permiten:
#
# - Determinar si existe dependencia o independencia entre variables
#
# - Validar si una diferencia en proporciones es estadísticamente significativa
#
# - Tomar decisiones basadas en evidencia, no en intuición
#
# En este contexto, herramientas como la prueba Chi-cuadrado se vuelven fundamentales para responder preguntas del tipo:
#
# “¿Estas dos variables están relacionadas o no?”

# %% [markdown]
# ---
#
# 1. 🎓 Género vs Aprobación
#
# Variable 1: Género (Masculino / Femenino)
#
# Variable 2: Resultado (Aprueba / No aprueba)
#
# 👉 Pregunta:
# ¿El resultado del curso depende del género o son independientes?
#
# ---
#
# 2. 🛒 Tipo de cliente vs Compra
#
# Variable 1: Tipo de cliente (Nuevo / Frecuente)
#
# Variable 2: Compra (Sí / No)
#
# 👉 Pregunta:
# ¿Los clientes frecuentes compran más que los nuevos o es casualidad?
#
# ---
#
# 3. 📱 Sistema operativo vs Preferencia de app
#
# Variable 1: Sistema (Android / iOS)
#
# Variable 2: Usa app (Sí / No)
#
# 👉 Pregunta:
# ¿El uso de la app depende del sistema operativo?
#
# ---

# %%
# Lista de campos #
data.info()

# %%
data.head(10)

# %%
# Variables Categóricas de Interés #
cols = ['situacion_laboral_del_jefe_del_hogar',
        'nivel_educativo_del_jefe_del_hogar', 
        'genero_del_jefe_del_hogar', 
        'tenencia_de_la_vivienda', 
        'zona_urbana_rural',
        'tipo_de_vivienda']

# Tabla Resumen #
resumen = pd.DataFrame({
    col: pd.Series(data[col].unique())
    for col in cols
})

resumen

# %%
# Función Dashboard para analizar variables categóricas #
import matplotlib.pyplot as plt
import seaborn as sns

def dashboard_categoricas(df, cols, top_n=6):
    
    # Estilo general
    sns.set_style("whitegrid")
    plt.rcParams.update({
        "axes.titlesize": 12,
        "axes.labelsize": 10
    })
    
    n = len(cols)
    cols_grid = 3
    rows = (n // cols_grid) + (n % cols_grid > 0)
    
    fig, axes = plt.subplots(rows, cols_grid, figsize=(20, 6 * rows))
    axes = axes.flatten()
    
    # Título principal
    fig.suptitle(
        "Dashboard de Variables Categóricas",
        fontsize=20,
        fontweight="bold",
        y=1.02
    )
    
    for i, col in enumerate(cols):
        ax = axes[i]
        
        # Conteo
        conteo = df[col].value_counts(dropna=False).head(top_n)
        total = conteo.sum()
        
        # Gráfico
        sns.barplot(
            x=conteo.values,
            y=conteo.index.astype(str),
            ax=ax
        )
        
        # Título individual
        ax.set_title(f"{col}", fontweight="bold")
        ax.set_xlabel("Frecuencia")
        ax.set_ylabel("")
        
        # Anotaciones (conteo + porcentaje)
        for j, v in enumerate(conteo.values):
            porcentaje = v / total * 100
            ax.text(
                v,
                j,
                f" {v} ({porcentaje:.1f}%)",
                va='center'
            )
    
    # Eliminar ejes vacíos
    for j in range(len(cols), len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.show()

# %%
# Ejecución de la Función Dashboard #
dashboard_categoricas(data, cols)

# %% [markdown]
# # Prueba de Independencia Chi-cuadrado
#
# ### Objetivo
#
# Evaluar si dos variables categóricas están relacionadas o si son independientes.
#
# ---
#
# ### Planteamiento de hipótesis
#
# $H_0$ : Las variables son independientes (no hay relación)
#
# $H_a$ : Las variables son dependientes (sí hay relación)
#
# ---
#
# ### Idea clave
#
# Se compara:
#
# 🔹 Frecuencias observadas (datos reales)
#
# 🔹 Frecuencias esperadas (si no hubiera relación)
#
# 👉 Si hay mucha diferencia → hay evidencia de dependencia
#
# ---
#
# ### Estadístico de prueba
#
# $$χ^2 = \sum\frac{(O_{ij}-E_{ij})^2}{E_{ij}}$$
#
# 🔹 $O_{ij}$ : Frecuencia Observada
#
# 🔹 $E_{ij}$ : Frecuencia Esperada
#
# ---
#
# ### ¿Cómo se calculan las esperadas?
#
# Bajo independencia:
#
# $$E_{ij} = \frac{(total\ fila\ i)×(total\ columna\ j)​}{total\ general} $$

# %% [markdown]
# ## Intuición de la Prueba
#
# “Si las variables fueran independientes, los datos deberían verse ‘balanceados’"
#
# "Si no lo están → hay relación”

# %%
import pandas as pd
from scipy.stats import chi2_contingency

def prueba_independencia(df, var1, var2, alpha=0.05):
    
    print(f"\n{'='*50}")
    print(f"🔍 {var1} vs {var2}")
    print(f"{'='*50}\n")
    
    # =========================
    # Tabla de contingencia
    # =========================
    tabla = pd.crosstab(df[var1], df[var2], margins=True)
    print("📊 Tabla de contingencia:")
    display(tabla)
    
    # =========================
    # Chi-cuadrado
    # =========================
    tabla_sin_totales = pd.crosstab(df[var1], df[var2])
    
    chi2, p, dof, expected = chi2_contingency(tabla_sin_totales)
    
    print("\n📈 Resultados prueba Chi-cuadrado:")
    print(f"Chi2: {chi2:.4f}")
    print(f"p-value: {p:.6f}")
    print(f"Grados de libertad: {dof}")
    
    # =========================
    # Decisión
    # =========================
    print("\n🧠 Decisión:")
    if p < alpha:
        print("✅ Se rechaza H0 → Las variables SON dependientes")
    else:
        print("❌ No se rechaza H0 → No hay evidencia de dependencia")
    
    # =========================
    # Frecuencias esperadas
    # =========================
    expected_df = pd.DataFrame(
        expected,
        index=tabla_sin_totales.index,
        columns=tabla_sin_totales.columns
    )
    
    print("\n📊 Frecuencias esperadas:")
    display(expected_df.round(2))

# %%
# Ejecutar a dos variables #
prueba_independencia(
    data,
    'genero_del_jefe_del_hogar',
    'tenencia_de_la_vivienda'
)

# %%
# Ejecutar de forma iterada dos a dos #
from itertools import combinations

cols = [
    'situacion_laboral_del_jefe_del_hogar',
    'nivel_educativo_del_jefe_del_hogar', 
    'genero_del_jefe_del_hogar', 
    'tenencia_de_la_vivienda', 
    'zona_urbana_rural'
]

for var1, var2 in combinations(cols, 2):
    prueba_independencia(data, var1, var2)

# %%
# Función de Pruebas que Incluye mapas de calor #
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

def prueba_independencia_pro(df, var1, var2, alpha=0.05):
    
    print(f"\n{'='*60}")
    print(f"🔍 {var1} vs {var2}")
    print(f"{'='*60}\n")
    
    # =========================
    # Tabla de contingencia
    # =========================
    tabla = pd.crosstab(df[var1], df[var2])
    print("📊 Tabla de contingencia:")
    display(tabla)
    
    # =========================
    # Chi-cuadrado
    # =========================
    chi2, p, dof, expected = chi2_contingency(tabla)
    
    print("\n📈 Chi-cuadrado:")
    print(f"Chi2: {chi2:.4f}")
    print(f"p-value: {p:.6f}")
    print(f"Grados de libertad: {dof}")
    
    # =========================
    # Decisión
    # =========================
    print("\n🧠 Decisión:")
    if p < alpha:
        print("✅ Se rechaza H0 → Hay dependencia")
    else:
        print("❌ No se rechaza H0 → No hay evidencia de dependencia")
    
    # =========================
    # Frecuencias esperadas
    # =========================
    expected_df = pd.DataFrame(
        expected,
        index=tabla.index,
        columns=tabla.columns
    )
    
    print("\n📊 Frecuencias esperadas:")
    display(expected_df.round(2))
    
    # =========================
    # Validación (regla de 5)
    # =========================
    bajos = (expected < 5).sum()
    total_celdas = expected.size
    
    print("\n⚠️ Validación supuestos:")
    print(f"Celdas con frecuencia esperada < 5: {bajos}/{total_celdas}")
    
    if bajos / total_celdas > 0.2:
        print("⚠️ Advertencia: Muchas celdas con valores bajos (resultado poco confiable)")
    else:
        print("✅ Supuestos razonablemente cumplidos")
    
    # =========================
    # V de Cramer
    # =========================
    n = tabla.values.sum()
    k = min(tabla.shape) - 1
    
    cramer_v = np.sqrt(chi2 / (n * k))
    
    print("\n📏 V de Cramer (fuerza de asociación):")
    print(f"V: {cramer_v:.4f}")
    
    # Interpretación
    if cramer_v < 0.1:
        print("Relación muy débil")
    elif cramer_v < 0.3:
        print("Relación débil")
    elif cramer_v < 0.5:
        print("Relación moderada")
    else:
        print("Relación fuerte")
    
    # =========================
    # Heatmap (🔥 visual potente)
    # =========================
    plt.figure(figsize=(8, 5))
    sns.heatmap(tabla, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Heatmap: {var1} vs {var2}")
    plt.xlabel(var2)
    plt.ylabel(var1)
    plt.show()

# %%
# Ejecución para dos variables #
prueba_independencia_pro(
    data,
    'genero_del_jefe_del_hogar',
    'tenencia_de_la_vivienda'
)

# %%
# Ejecución para Variables dos a dos #
from itertools import combinations

for v1, v2 in combinations(cols, 2):
    prueba_independencia_pro(data, v1, v2)

# %% [markdown]
# # Mutual Information (Información Mutua)
#
# ## Definición
#
# La Información Mutua (MI) mide cuánta información comparte una variable con otra.
#
# En otras palabras : ¿Cuánto saber $X$ reduce la incertidumbre sobre $Y$?
#
# ---

# %% [markdown]
# ## Definición Formal
#
# $$I(X;Y) = \sum_{x \in \mathcal{X}} \sum_{y \in \mathcal{Y}}
# p(x,y) \log \left( \frac{p(x,y)}{p(x)\,p(y)} \right)
# $$
#
# ---
#
# ### Interpretación intuitiva
#
# 🔹 $MI = 0$ → Variables independientes
#
# 🔹 $MI > 0$ → Hay dependencia
#
# 🔹 Mayor $MI$ → Mayor relación
#
# ---
#
# ### A diferencia de Chi-cuadrado:
#
# 🔹 No depende de supuestos fuertes
#
# 🔹 Detecta relaciones no lineales y complejas

# %%
import pandas as pd
from sklearn.feature_selection import mutual_info_classif

# Variables
cols = [
    'situacion_laboral_del_jefe_del_hogar',
    'nivel_educativo_del_jefe_del_hogar', 
    'genero_del_jefe_del_hogar', 
    'tenencia_de_la_vivienda', 
    'zona_urbana_rural'
]

# Copia
df_encoded = data[cols].copy()

# Codificar categóricas (clave)
for col in df_encoded.columns:
    df_encoded[col] = df_encoded[col].astype('category').cat.codes

# Definir X e y
X = df_encoded.drop(columns=['tenencia_de_la_vivienda'])
y = df_encoded['tenencia_de_la_vivienda']

# Calcular MI
mi = mutual_info_classif(X, y, discrete_features=True)

# Resultado ordenado
resultado = pd.Series(mi, index=X.columns).sort_values(ascending=False)

print("Información Mutua con Tenencia de la Vivienda")
print()
print(resultado)

# %%
# Graficando la Información Mutua #
import matplotlib.pyplot as plt

resultado.sort_values().plot(kind='barh')
plt.title("Importancia de Variables (Mutual Information)")
plt.xlabel("MI")
plt.show()

# %% [markdown]
# # 3. Variables Continuas vs Categóricas
#
# ## ANOVA
#
# ### Definición
#
# Evalúa si la media de una variable continua cambia entre grupos definidos por una variable categórica.
#
# ¿Los grupos son realmente diferentes o las diferencias son puro ruido?
#
# ---
#
# ## t-test
#
# ### Hipótesis
#
# - $H_0:$ Todas las medias son iguales
# - $H_a:$ Al menos una media es diferente
#
# ---
#
# ### Idea
#
# $$F = \frac{\text{Varianza entre grupos}}{\text{Varianza dentro de grupos}}$$
#
# ---
#
# ### Interpretación
#
# - F grande → diferencias significativas
#
# - Si los grupos son muy distintos → F grande → ❌ Rechazamos H₀
#
# - Si son similares → F pequeño → ✅ No rechazamos

# %% [markdown]
# ---
#
# # Ejemplos
#
# ---
#
# 🔹 **Educación vs Ingresos**
# - ¿El ingreso promedio cambia según el nivel educativo?
#
# ---
#
# 🔹 **Zona vs Valor de vivienda**
# - ¿El valor promedio cambia entre zona urbana y rural?
#
# ---
#
# 🔹 **Tipo de empleo vs gasto mensual**
# - ¿El gasto cambia según la situación laboral?
# ---

# %% [markdown]
# <p align="center">
#   <img src="img/anova.png" width="700" height="500">
# </p>

# %%
# Campos en una Columna #
data.columns.to_list()

# %% [markdown]
# ## **¿El ingreso promedio cambia según el nivel educativo?**

# %%
# Prueba ANOVA #
from scipy import stats

grupos = [
    data[data['nivel_educativo_del_jefe_del_hogar'] == cat]['ingreso_del_hogar']
    for cat in data['nivel_educativo_del_jefe_del_hogar'].unique()
]

F, p = stats.f_oneway(*grupos)

print("F:", F)
print("p-value:", p)

if p < 0.05:
    print("❌ Hay diferencias entre niveles educativos")
else:
    print("✅ No hay diferencias significativas")

# %%
# Gráfico Ilustrativo #
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

# Boxplot (estructura de las distribuciones)
sns.boxplot(
    x=data['nivel_educativo_del_jefe_del_hogar'],
    y=data['ingreso_del_hogar']
)

# Puntos individuales (para ver dispersión real)
sns.stripplot(
    x=data['nivel_educativo_del_jefe_del_hogar'],
    y=data['ingreso_del_hogar'],
    color='black',
    alpha=0.4
)

plt.title("Ingresos del Hogar según Nivel Educativo", fontsize=16)
plt.xlabel("Nivel Educativo del Jefe del Hogar")
plt.ylabel("Ingreso del Hogar")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
# Gráfico Alternativo #
sns.pointplot(
    x=data['nivel_educativo_del_jefe_del_hogar'],
    y=data['ingreso_del_hogar'],
    estimator='mean',
    color='red',
    markers='D'
)

# %% [markdown]
# ## **¿El valor promedio cambia entre zona urbana y rural?**

# %%
# Prueba ANOVA #
from scipy import stats

grupos = [
    data[data['zona_urbana_rural'] == cat]['valor_de_mercado_de_la_vivienda']
    for cat in data['zona_urbana_rural'].unique()
]

F, p = stats.f_oneway(*grupos)

print("F:", F)
print("p-value:", p)

if p < 0.05:
    print("❌ Hay diferencias entre las zonas")
else:
    print("✅ No hay diferencias significativas")

# %%
# Gráfico Ilustrativo #
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

# Boxplot (estructura de las distribuciones)
sns.boxplot(
    x=data['zona_urbana_rural'],
    y=data['valor_de_mercado_de_la_vivienda']
)

# Puntos individuales (para ver dispersión real)
sns.stripplot(
    x=data['zona_urbana_rural'],
    y=data['valor_de_mercado_de_la_vivienda'],
    color='black',
    alpha=0.4
)

plt.title("Valor de la Vivienda según la Zona", fontsize=16)
plt.xlabel("Zona")
plt.ylabel("Valor de la Vivienda")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **¿El gasto cambia según la situación laboral?**

# %%
# Prueba ANOVA #
from scipy import stats

grupos = [
    data[data['acceso_a_credito'] == cat]['indice_de_pobreza']
    for cat in data['acceso_a_credito'].unique()
]

F, p = stats.f_oneway(*grupos)

print("F:", F)
print("p-value:", p)

if p < 0.05:
    print("❌ Hay diferencias entre los estratos")
else:
    print("✅ No hay diferencias significativas")

# %%
# Gráfico Ilustrativo #
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

# Boxplot (estructura de las distribuciones)
sns.boxplot(
    x=data['acceso_a_credito'],
    y=data['indice_de_pobreza']
)

# Puntos individuales (para ver dispersión real)
sns.stripplot(
    x=data['acceso_a_credito'],
    y=data['indice_de_pobreza'],
    color='black',
    alpha=0.4
)

plt.title("Acceso de Crédito según Índice de Pobreza", fontsize=16)
plt.xlabel("Acceso a Crédito")
plt.ylabel("Índice de Pobreza")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# # ANOVA No Paramétrica
#
# ### Prueba de Kruskal–Wallis
#
# Es una prueba no paramétrica que evalúa si las distribuciones de una variable continua difieren entre varios grupos (definidos por una variable categórica). En lugar de comparar medias, compara rangos, ordena todos los datos y analiza si los grupos tienden a tener valores más altos o más bajos.
#
# Es el “ANOVA sin supuestos fuertes”.
#
# ---
#
# ### Hipótesis
#
# $H_0:$ Las distribuciones (medianas) son iguales
#
# $H_a:$ Al menos una es diferente
#
# ---
#
# ### Estadístico
#
# $$H = \frac{12}{N(N+1)} \sum_{i=1}^{k} n_i \bar{R}_i^{\,2} - 3(N+1)$$
#
# ---
#
# ### Cuándo usarla
#
# - No hay normalidad
# - Hay outliers
# - Variables ordinales o continuas no normales
#
#
# | ANOVA               | Kruskal-Wallis |
# | ------------------- | -------------- |
# | Usa medias          | Usa rangos     |
# | Paramétrica         | No paramétrica |
# | Sensible a outliers | Robusta        |

# %%
# Función Base para la Prueba #
from scipy import stats

def kruskal_test(data, x, y, alpha=0.05):
    """
    x: variable categórica
    y: variable continua
    """
    grupos = [
        data[data[x] == cat][y].dropna()
        for cat in data[x].dropna().unique()
    ]
    
    H, p = stats.kruskal(*grupos)
    
    print(f"📊 Variable categórica: {x}")
    print(f"📈 Variable continua: {y}")
    print(f"H = {H:.4f}")
    print(f"p-value = {p:.4f}")
    
    if p < alpha:
        print("❌ Se rechaza H₀ → Hay diferencias significativas entre grupos\n")
    else:
        print("✅ No se rechaza H₀ → No hay evidencia de diferencias entre grupos\n")

# %%
kruskal_test(
    data,
    x='nivel_educativo_del_jefe_del_hogar',
    y='ingreso_del_hogar'
)

# %%
kruskal_test(
    data,
    x='zona_urbana_rural',
    y='valor_de_mercado_de_la_vivienda'
)

# %%
kruskal_test(
    data,
    x='acceso_a_credito',
    y='indice_de_pobreza'
)

# %% [markdown]
# ### **Esto te dice exactamente qué grupos difieren**

# %%
# Grupos que Difieren #
import scikit_posthocs as sp

sp.posthoc_dunn(
    data,
    val_col='ingreso_del_hogar',
    group_col='nivel_educativo_del_jefe_del_hogar',
    p_adjust='bonferroni'
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

resultado = sp.posthoc_dunn(
    data,
    val_col='ingreso_del_hogar',
    group_col='nivel_educativo_del_jefe_del_hogar',
    p_adjust='bonferroni'
)

plt.figure(figsize=(8,6))
sns.heatmap(resultado, annot=True, cmap="coolwarm", fmt=".3f")

plt.title("Dunn Test (p-values)")
plt.show()

# %% [markdown]
# ## Función Unificadora de Pruebas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

def analisis_completo(data, x, y, alpha=0.05):
    
    # -------------------------
    # LIMPIEZA
    # -------------------------
    df = data[[x, y]].dropna()
    
    # -------------------------
    # GRÁFICO
    # -------------------------
    plt.figure(figsize=(10,6))
    
    sns.boxplot(x=df[x], y=df[y])
    sns.stripplot(x=df[x], y=df[y], alpha=0.4)
    
    plt.title(f"{y} vs {x}", fontsize=16)
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
    
    # -------------------------
    # AGRUPACIÓN
    # -------------------------
    grupos = [
        df[df[x] == cat][y]
        for cat in df[x].unique()
    ]
    
    # -------------------------
    # ANOVA
    # -------------------------
    F, p_anova = stats.f_oneway(*grupos)
    
    # -------------------------
    # KRUSKAL
    # -------------------------
    H, p_kruskal = stats.kruskal(*grupos)
    
    # -------------------------
    # RESULTADOS
    # -------------------------
    print("📊 RESULTADOS ESTADÍSTICOS\n")
    
    print(f"ANOVA → F = {F:.4f}, p-value = {p_anova:.4f}")
    if p_anova < alpha:
        print("❌ ANOVA: Hay diferencias entre medias")
    else:
        print("✅ ANOVA: No hay diferencias significativas")
    
    print("\n----------------------------------\n")
    
    print(f"Kruskal-Wallis → H = {H:.4f}, p-value = {p_kruskal:.4f}")
    if p_kruskal < alpha:
        print("❌ Kruskal: Hay diferencias entre distribuciones")
    else:
        print("✅ Kruskal: No hay diferencias significativas")
    
    # -------------------------
    # CONCLUSIÓN AUTOMÁTICA
    # -------------------------
    print("\n🎯 CONCLUSIÓN FINAL:")
    
    if p_anova < alpha and p_kruskal < alpha:
        print("👉 Ambas pruebas coinciden: hay evidencia sólida de diferencias entre grupos.")
    
    elif p_anova < alpha and p_kruskal >= alpha:
        print("👉 ANOVA detecta diferencias, pero Kruskal no → posible efecto de outliers o no normalidad.")
    
    elif p_anova >= alpha and p_kruskal < alpha:
        print("👉 Kruskal detecta diferencias, pero ANOVA no → relación no lineal o distribuciones no normales.")
    
    else:
        print("👉 Ambas pruebas coinciden: no hay evidencia de diferencias entre grupos.")

# %%
analisis_completo(
    data,
    x='nivel_educativo_del_jefe_del_hogar',
    y='ingreso_del_hogar'
)

# %%
analisis_completo(
    data,
    x='zona_urbana_rural',
    y='valor_de_mercado_de_la_vivienda'
)

# %%
analisis_completo(
    data,
    x='acceso_a_credito',
    y='indice_de_pobreza'
)

# %% [markdown]
# ---
# # **¡FIN!**
# ---
