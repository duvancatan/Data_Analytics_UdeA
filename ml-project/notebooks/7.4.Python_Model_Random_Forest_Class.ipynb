# %% [markdown]
# ---
#
# <div style="text-align: justify; line-height: 1.5; font-size: 18px;">
#
# <h1 align="center"><b>Clasificación Random Forest con Scikit-Learn</b></h1>
#
# ---
#
# Un modelo **Random Forest** está compuesto por un conjunto de Árboles de Decisión individuales. Cada uno de estos árboles es entrenado con una muestra aleatoria extraída de los datos de entrenamiento originales mediante *bootstrapping*. Esto implica que cada árbol se entrena con un conjunto de datos ligeramente diferente. En cada árbol individual, las observaciones se distribuyen a través de nodos, dando forma a la estructura del árbol hasta llegar a un nodo terminal. La predicción de una nueva observación se obtiene al agregar las predicciones de todos los árboles individuales que conforman el modelo.
#
# La documentación para su implementación con Scikit-Learn puede ser consultada en 🔗 <a href="https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html"> RandomForestClassifier</a>
#
#
#
# </div>
#
# ---

# %% [markdown]
# <p align="center">
#  <img src="img/rf_img.png" width="1100" height="650">
# </p>

# %% [markdown]
# <div style="text-align: justify; line-height: 1.5; font-size: 18px;">
#
# ### **1. Introducción**
#
# Random Forest es un algoritmo de aprendizaje supervisado basado en:
#
# - múltiples Árboles de Decisión,
#
# - muestreo aleatorio de observaciones,
#
# - selección aleatoria de variables,
#
# - y votación entre árboles.
#
# Fue propuesto por Leo Breiman y es uno de los métodos más utilizados en Machine Learning debido a:
#
# ✅ alta precisión
# ✅ robustez
# ✅ manejo de relaciones no lineales
# ✅ resistencia al sobreajuste
#
# ---
#
# ### **2. Idea Fundamental**
#
# - En lugar de construir un único árbol : ```1 árbol → alta varianza```
#
# - Random Forest construye : ```muchos árboles → promedio de decisiones```
#
# ---
#
# ### **3. Funcionamiento General**
#
# El algoritmo:
#
# 1. genera múltiples muestras Bootstrap,
#
# 2. construye un árbol para cada muestra,
#
# 3. selecciona subconjuntos aleatorios de variables,
#
# 4. cada árbol realiza una predicción,
#
# 5. el bosque vota la clase final.
#
# ---
#
# ### **4. Bootstrap Sampling**
#
# Cada árbol se entrena con una muestra aleatoria del dataset.
#
# - Si el dataset tiene: $N$ observaciones,
#
# - cada árbol recibe: $N$ muestras seleccionadas con reemplazo.
#
# ---
#
# ### **5. Submuestreo Aleatorio de Variables**
#
# - En cada nodo, **Random Forest** selecciona aleatoriamente $m$ variables de las $p$ variables disponibles.
#
# - Luego busca la mejor división únicamente entre esas variables.
#
# ---
#
# ### **6. Clasificación Final por Votación**
#
# Supongamos:
#
# - 100 árboles,
#
# - problema binario.
#
# - Cada árbol produce: $\hat{y}^{(b)}$, para $b=1,\dots,B$
#
# - **Predicción final** : La clasificación final se obtiene mediante:
#
# $$
# \hat{y}
# =
# \text{Moda}
# \left(
# \hat{y}^{(1)},
# \hat{y}^{(2)},
# \dots,
# \hat{y}^{(B)}
# \right)
# $$
#
# </div>
#
#  ---

# %% [markdown]
# <div style="text-align: justify; line-height: 1.5; font-size: 18px;">
#
# ### **7. Importancia de Variables**
#
# Random Forest permite medir : ```Feature Importance```
#
# ---
#
# **Idea**
#
# Una variable es importante si:
#
# - reduce mucho la impureza
#
# - aparece frecuentemente en divisiones
#
# ---
#
# **Importancia Total**
#
# La importancia se calcula acumulando : $\Delta I$, reducciones de impureza.
#
# ---
#
# **Fórmula Conceptual**
#
# $$
# FI_j
# =
# \sum
# \Delta I_j
# $$
#
# donde:
#
# - $FI_j$ = importancia variable $j$,
#
# - $\Delta I_j$ = reducción de impureza.
#
# ---
#
# **Interpretación**
#
# Mayor importancia:
#
# - variable más influyente.
#
# </div>
#
#  ---

# %% [markdown]
# <div style="text-align: justify; line-height: 1.5; font-size: 18px;">
#
# ## **Hiperparámetros Importantes**
#
# ---
#
#  - **Número de árboles**
#
# ```python
# n_estimators
# ```
#
# Cantidad de árboles: $B$
#
# ---
#
# - **Profundidad máxima**
#
# ```python
# max_depth
# ```
#
# Controla complejidad del árbol.
#
# ---
#
# - **Variables por nodo**
#
# ```python
# max_features
# ```
#
# Número de variables candidatas en cada división.
#
# ---
#
# - **Muestras mínimas**
#
# ```python
# min_samples_split
# ```
#
# Mínimo para dividir nodos.
#
# ---
#
# - **Hojas mínimas**
#
# ```python
# min_samples_leaf
# ```
#
# Mínimo de observaciones por hoja.
#
# ---
#
# - **Criterio**
#
# ```python
# criterion
# ```
#
# Puede ser: ```gini``` o ```entropy```
#
# ---
# ---
#
# <div align="center">
#
# |  | **Aspecto** | **Descripción** |
# |---|---|---|
# ||||
# | ✅ Ventajas | Alta precisión | Suele lograr excelente desempeño predictivo en problemas de clasificación y regresión. |
# |  | Reduce sobreajuste | El promedio de múltiples árboles disminuye la varianza del modelo. |
# |  | No requiere escalamiento | Funciona correctamente sin normalizar o estandarizar variables. |
# |  | Captura relaciones no lineales | Modela patrones complejos y fronteras de decisión no lineales. |
# |  | Robusto a outliers | Los valores extremos afectan poco el desempeño global. |
# |  | Maneja muchas variables | Puede trabajar con datasets de alta dimensionalidad. |
# ||||
# | ❌ Desventajas | Menor interpretabilidad | Es más difícil de interpretar que un único árbol de decisión. |
# |  | Mayor costo computacional | Entrenar cientos de árboles puede requerir más tiempo y recursos. |
# |  | Puede ser lento | Las predicciones pueden tardar más en modelos grandes. |
# |  | Alto consumo de memoria | El almacenamiento de múltiples árboles incrementa el uso de memoria. |
#
#  </div>
#
#
#  </div>
#
#  ---

# %% [markdown]
# ---
#
# <div style="text-align: justify; line-height: 1.5; font-size: 18px;">
#
# ### **Implementación Básica**
#
# ```python
# from sklearn.ensemble import RandomForestClassifier
#
# model = RandomForestClassifier(
#
#     n_estimators=200,
#
#     criterion="gini",
#
#     max_depth=10,
#
#     random_state=123
#
# )
# ```
#
#  </div>

# %% [markdown]
# ---
# ---
#
# <div style="text-align: justify; line-height: 1.5; font-size: 18px;">
#
# <h1 align="center"><b>Modelación con Clasificación Random Forest - Spam</b></h1>
#
# En este proyecto, se construyo un clasificador para predecir la clasificación de un correo electrónico es Spam o no. Se desarrolla modelos basados con el índice de Gini y entropía como criterio. Se emplea el conjunto de datos de correos electrónicos, el cual se encuentra en la carpeta ```ml-project/data/spam```.
#
# </div>
#
# ---

# %%
# ============ #
# 1. LIBRERÍAS #
# ============ #

import numpy as np
import pandas as pd
import os
import plotly.express as px
import plotly.graph_objects as go
import joblib
from pathlib import Path
from sklearn.model_selection import (train_test_split, cross_validate, RandomizedSearchCV)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve
)

# %%
# =================== #
# 2. LECTURA DE RUTAS #
# =================== #

mainpath= "/Users/duvancatano/Documents/Data_Analytics_UdeA/ml-project/data/spam"
filename= "spam_dataset.csv"
fullpath= os.path.join(mainpath,filename)

# %%
# ================= #
# 3. CARGA DE DATOS #
# ================= #

data = pd.read_csv(fullpath, sep=",") # El separador es "," porque en el archivo .csv los valores están separados por coma
pd.set_option('display.max_columns', None) # Para mostrar todas las columnas del DataFrame sin truncar
data.sample(10)

# %%
# ==================================== #
# 4. CODIFICACIÓN DE VARIABLE OBJETIVO #
# ==================================== #

# 1 = Spam
# 0 = No Spam

data["type"] = np.where(

    data["type"] == "spam",

    1,

    0

)

# %%
# ============================================================================== #
# 5. VARIABLES PREDICTORAS Y OBJETIVO
# ============================================================================== #

X = data.drop(columns="type")
y = data["type"]

# %%
# ==================================== #
# 6. VARIABLES NUMÉRICAS Y CATEGÓRICAS #
# ==================================== #

cat_cols = X.select_dtypes(
    include=["object", "category"]
).columns.tolist() # Aunque no tenemos categóricas, se deja si en el futuro se incluye alguna

num_cols = X.select_dtypes(
    include=["int64", "float64"]
).columns.tolist() # Se combina variables de tipo entero y real

# %%
# =================== #
# 7. PREPROCESAMIENTO #
# =================== #

preprocessor = ColumnTransformer([
    ("cat", OneHotEncoder(drop="first", handle_unknown="ignore"), cat_cols) ], 
                                 remainder="passthrough"
                                 )

# %%
# ========================= #
# 8. PARTICIÓN TRAIN - TEST #
# ========================= #

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, stratify=y, random_state=123)

# %%
# =========== #
# 9. PIPELINE #
# =========== #

pipeline_rf = Pipeline([
    ("preprocessing", preprocessor),
    (
        "model",
        RandomForestClassifier(
            random_state=123,
            oob_score=True
        )
    )
])

# %%
# ================= #
# 10. ENTRENAMIENTO #
# ================= #

pipeline_rf.fit(X_train, y_train)

# %%
# ================ #
# 11. PREDICCIONES #
# ================ #

y_pred = pipeline_rf.predict(X_test)

y_prob = pipeline_rf.predict_proba(X_test)[:,1]

# %%
# ============ #
# 12. MÉTRICAS #
# ============ #

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)

# %%
# ============== #
# 13. RESULTADOS #
# ============== #

print("="*22)
print("MÉTRICAS RANDOM FOREST")
print("="*22)
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-Score : {f1:.4f}")
print(f"ROC-AUC  : {roc_auc:.4f}")

# %%
# ======================= #
# 14. MATRIZ DE CONFUSIÓN #
# ======================= #

cm = confusion_matrix(
    y_test,
    y_pred
)

cm_df = pd.DataFrame(
    cm,
    index=[
        "Real No Spam",
        "Real Spam"
    ],

    columns=[
        "Pred No Spam",
        "Pred Spam"
    ]
)

fig = px.imshow(
    cm_df,
    text_auto=True,
    color_continuous_scale="Reds",
    title="Matriz de Confusión"
)

fig.update_layout(
    template="plotly_dark",
    title_x=0.5,
    height=600

)

fig.show()

# %%
# ========================= #
# 15. CLASSIFICATION REPORT #
# ========================= #

print("")
print("="*22)
print("CLASSIFICATION REPORT")
print("="*22)
print(
    classification_report(
        y_test,
        y_pred
    )
)

# %%
# ============= #
# 16. CURVA ROC #
# ============= #

fpr, tpr, thresholds = roc_curve(
    y_test,
    y_prob
)

fig = px.area(
    x=fpr,
    y=tpr,
    title=f"Curva ROC (AUC = {roc_auc:.4f})"
)

fig.add_shape(
    type="line",
    line=dict(
        dash="dash"
    ),
    x0=0,
    x1=1,
    y0=0,
    y1=1
)

fig.update_layout(
    template="plotly_dark",
    title={
        "text": f"Curva ROC (AUC = {roc_auc:.4f})",
        "x": 0.5,
        "xanchor": "center"
    },
    xaxis_title="False Positive Rate",
    yaxis_title="True Positive Rate",
    height=600
)

fig.show()

# %% [markdown]
# ---
# ## **Validación Cruzada**
# ---

# %%
# ====================== #
# 17. VALIDACIÓN CRUZADA #
# ====================== #

cv_results = cross_validate(
    pipeline_rf,
    X_train,
    y_train,
    cv=5,
    scoring=[
        "accuracy",
        "precision",
        "recall",
        "f1",
        "roc_auc"
    ],
    return_train_score=False
)

# %%
# ================================= #
# 18. RESULTADOS VALIDACIÓN CRUZADA #
# ================================= #

print("")
print("="*18)
print("VALIDACIÓN CRUZADA")
print("="*18)
print(f"Accuracy CV : {cv_results['test_accuracy'].mean():.4f}")
print(f"Precision CV: {cv_results['test_precision'].mean():.4f}")
print(f"Recall CV   : {cv_results['test_recall'].mean():.4f}")
print(f"F1-Score CV : {cv_results['test_f1'].mean():.4f}")
print(f"ROC-AUC CV  : {cv_results['test_roc_auc'].mean():.4f}")

# %%
# ================= #
# 19. RANDOM SEARCH #
# ================= #

param_dist = {
    "model__oob_score": [
        True
    ],
    
    "model__criterion": [
        "gini",
        "entropy"
    ],
    
    "model__n_estimators": [
        100,
        200,
        300,
        500
    ],

    "model__max_depth": [
        None,
        5,
        10,
        20,
        30
    ],

    "model__min_samples_split": [
        2,
        5,
        10
    ],

    "model__min_samples_leaf": [
        1,
        2,
        4
    ],

    "model__max_features": [
        "sqrt",
        "log2",
        None
    ],

    "model__bootstrap": [
        True,
        False
    ],

    "model__class_weight": [
        None,
        "balanced"
    ]
}

# %%
# ======================== #
# 20. RANDOMIZED SEARCH CV #
# ======================== #

random_search = RandomizedSearchCV(
    estimator=pipeline_rf,
    param_distributions=param_dist,
    n_iter=30,
    scoring="roc_auc",
    cv=5,
    verbose=1,
    random_state=123,
    n_jobs=-1
)

# %%
# =============================== #
# 21. ENTRENAMIENTO RANDOM SEARCH #
# =============================== #

random_search.fit(
    X_train,
    y_train
)

# %%
# ================ #
# 22. MEJOR MODELO #
# ================ #

best_model = random_search.best_estimator_

# %%
# =========================== #
# 23. MEJORES HIPERPARÁMETROS #
# =========================== #

print("")
print("="*70)
print("MEJORES HIPERPARÁMETROS")
print("="*70)

for key, value in random_search.best_params_.items():

    print(f"{key}: {value}")

# %%
# ============================= #
# 24. PREDICCIONES MEJOR MODELO #
# ============================= #

y_pred_best = best_model.predict(X_test)
y_prob_best = best_model.predict_proba(X_test)[:,1]

# %%
# ========================= #
# 25. MÉTRICAS MEJOR MODELO #
# ========================= #

print("")
print("="*23)
print("MÉTRICAS MEJOR MODELO")
print("="*23)
print(f"Accuracy : {accuracy_score(y_test, y_pred_best):.4f}")
print(f"Precision: {precision_score(y_test, y_pred_best):.4f}")
print(f"Recall   : {recall_score(y_test, y_pred_best):.4f}")
print(f"F1-Score : {f1_score(y_test, y_pred_best):.4f}")
print(f"ROC-AUC  : {roc_auc_score(y_test, y_prob_best):.4f}")

# %%
# ============================ #
# 26. IMPORTANCIA DE VARIABLES #
# ============================ #

feature_names = (
    best_model
    .named_steps["preprocessing"]
    .get_feature_names_out()
)

importances = (
    best_model
    .named_steps["model"]
    .feature_importances_
)

importance_df = pd.DataFrame({
    "Variable": feature_names,
    "Importancia": importances
})

importance_df = (
    importance_df
    .sort_values(
        by="Importancia",
        ascending=False
    )
)

# %%
# ==================================== #
# 27. TOP 20 VARIABLES MÁS IMPORTANTES #
# ==================================== #

top_importance = importance_df.head(20)

fig = px.bar(
    top_importance,
    x="Importancia",
    y="Variable",
    orientation="h",
    text="Importancia",
    color="Importancia",
    color_continuous_scale="Reds",
    title="Top 20 Variables Más Importantes"
)

fig.update_layout(
    template="plotly_dark",
    title_x=0.5,
    height=700,
    coloraxis_showscale=False
)

fig.update_yaxes(
    categoryorder="total ascending"
)

fig.update_traces(
    texttemplate="%{text:.4f}",
    textposition="outside"
)

fig.show()

# %%
# =========================================== #
# 28. ENTRENAMIENTO FINAL CON TODOS LOS DATOS #
# =========================================== #

final_model = Pipeline([
    ("preprocessing", preprocessor),
    (
        "model",
        RandomForestClassifier(
            n_estimators=random_search.best_params_[
                "model__n_estimators"
            ],
            max_depth=random_search.best_params_[
                "model__max_depth"
            ],
            min_samples_split=random_search.best_params_[
                "model__min_samples_split"
            ],

            min_samples_leaf=random_search.best_params_[
                "model__min_samples_leaf"
            ],

            max_features=random_search.best_params_[
                "model__max_features"
            ],

            bootstrap=random_search.best_params_[
                "model__bootstrap"
            ],

            class_weight=random_search.best_params_[
                "model__class_weight"
            ],

            random_state=123,
            n_jobs=-1
        )
    )
])

# %%
# ======================= #
# 29. ENTRENAMIENTO FINAL #
# ======================= #

final_model.fit(X, y)

# %% [markdown]
# ---
#
# ## **Serialización del Mejor Modelo**
#
# ---

# %%
# ======================================== #
# 30. CARPETA DONDE SE GUARDARÁ EL .joblib #
# ======================================== #
ruta = Path("/Users/duvancatano/Documents/Data_Analytics_UdeA/ml-project/models")

# Crear carpeta sino existe
ruta.mkdir(parents=True, exist_ok=True)

# %%
# ======================== #
# 31. GUARDAR MODELO FINAL #
# ======================== #

joblib.dump(final_model, ruta / "model_random_forest_classifier_spam.joblib")

# %%
# ===================== #
# 32. GUARDAR VARIABLES #
# ===================== #

joblib.dump(X.columns.tolist(), ruta / "features_random_forest_classifier_spam.joblib")

# %% [markdown]
# ---
# ## **Análisis con OOB**
# ---

# %%
# ======================== #
# 1. RANDOM SEARCH CON OOB #
# ======================== #

param_dist = {
    "model__criterion": [
        "gini",
        "entropy"
    ],

    "model__n_estimators": [
        100,
        200,
        300,
        500
    ],

    "model__max_depth": [
        None,
        5,
        10,
        20,
        30
    ],

    "model__min_samples_split": [
        2,
        5,
        10
    ],

    "model__min_samples_leaf": [
        1,
        2,
        4
    ],

    "model__max_features": [
        "sqrt",
        "log2",
        None
    ],

    "model__bootstrap": [
        True
    ],

    "model__class_weight": [
        None,
        "balanced"
    ]
}

# %%
# ================================= #
# 2. PIPELINE RANDOM FOREST CON OOB #
# ================================= #

pipeline_rf = Pipeline([
    ("preprocessing", preprocessor),
    ("model", RandomForestClassifier(
            oob_score=True,
            random_state=123,
            n_jobs=-1
        )
    )
])

# %%
# ======================= #
# 3. RANDOMIZED SEARCH CV #
# ======================= #

random_search = RandomizedSearchCV(
    estimator=pipeline_rf,
    param_distributions=param_dist,
    n_iter=30,
    scoring="roc_auc",
    cv=5,
    verbose=1,
    random_state=123,
    n_jobs=-1
)

# %%
# ============================== #
# 4. ENTRENAMIENTO RANDOM SEARCH #
# ============================== #

random_search.fit(
    X_train,
    y_train
)

# %%
# =============== #
# 5. MEJOR MODELO #
# =============== #

best_model = random_search.best_estimator_

# %%
# ========================== #
# 6. MEJORES HIPERPARÁMETROS #
# ========================== #

print("")
print("="*70)
print("MEJORES HIPERPARÁMETROS")
print("="*70)

for key, value in random_search.best_params_.items():

    print(f"{key}: {value}")

# %%
# ============ #
# 7. OOB SCORE #
# ============ #

oob_score = (
    best_model
    .named_steps["model"]
    .oob_score_
)

print("")
print("="*70)
print("OUT-OF-BAG SCORE")
print("="*70)
print(f"OOB Score: {oob_score:.4f}")

# %%
# =============== #
# 8. PREDICCIONES #
# =============== #

y_pred_best = best_model.predict(X_test)
y_prob_best = best_model.predict_proba(X_test)[:,1]

# %%
# =========== #
# 9. MÉTRICAS #
# =========== #

accuracy = accuracy_score(
    y_test,
    y_pred_best
)

precision = precision_score(
    y_test,
    y_pred_best
)

recall = recall_score(
    y_test,
    y_pred_best
)

f1 = f1_score(
    y_test,
    y_pred_best
)

roc_auc = roc_auc_score(
    y_test,
    y_prob_best
)

# %%
# ============== #
# 10. RESULTADOS #
# ============== #

print("")
print("="*70)
print("MÉTRICAS MEJOR MODELO")
print("="*70)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-Score : {f1:.4f}")
print(f"ROC-AUC  : {roc_auc:.4f}")

# %%
# ======================= #
# 11. MATRIZ DE CONFUSIÓN #
# ======================= #

cm = confusion_matrix(
    y_test,
    y_pred_best
)

cm_df = pd.DataFrame(
    cm,
    index=[
        "Real No Spam",
        "Real Spam"
    ],

    columns=[
        "Pred No Spam",
        "Pred Spam"
    ]
)

fig = px.imshow(
    cm_df,
    text_auto=True,
    color_continuous_scale="Reds",
    title="Matriz de Confusión"
)

fig.update_layout(
    template="plotly_dark",
    title_x=0.5,
    height=600
)

fig.show()

# %%
# ========================= #
# 12. CLASSIFICATION REPORT #
# ========================= #

print("")
print("="*70)
print("CLASSIFICATION REPORT")
print("="*70)

print(
    classification_report(
        y_test,
        y_pred_best
    )
)

# %%
# ============= #
# 13. CURVA ROC #
# ============= #

fpr, tpr, thresholds = roc_curve(
    y_test,
    y_prob_best
)

fig = px.area(
    x=fpr,
    y=tpr,
    title=f"Curva ROC (AUC = {roc_auc:.4f})"
)

fig.add_shape(
    type="line",
    line=dict(
        dash="dash"
    ),
    x0=0,
    x1=1,
    y0=0,
    y1=1

)

fig.update_layout(
    template="plotly_dark",
    title={
        "text": f"Curva ROC (AUC = {roc_auc:.4f})",
        "x": 0.5,
        "xanchor": "center"
    },

    xaxis_title="False Positive Rate",
    yaxis_title="True Positive Rate",
    height=600
)

fig.show()

# %%
# ============================ #
# 14. IMPORTANCIA DE VARIABLES #
# ============================ #

feature_names = (
    best_model
    .named_steps["preprocessing"]
    .get_feature_names_out()
)

importances = (
    best_model
    .named_steps["model"]
    .feature_importances_
)

importance_df = pd.DataFrame({
    "Variable": feature_names,
    "Importancia": importances
})

importance_df = (
    importance_df
    .sort_values(
        by="Importancia",
        ascending=False
    )
)

# %%
# ==================================== #
# 15. TOP 20 VARIABLES MÁS IMPORTANTES #
# ==================================== #

top_importance = importance_df.head(20)

fig = px.bar(
    top_importance,
    x="Importancia",
    y="Variable",
    orientation="h",
    text="Importancia",
    color="Importancia",
    color_continuous_scale="Reds",
    title="Top 20 Variables Más Importantes"
)

fig.update_layout(
    template="plotly_dark",
    title_x=0.5,
    height=700,
    coloraxis_showscale=False
)

fig.update_yaxes(
    categoryorder="total ascending"
)

fig.update_traces(
    texttemplate="%{text:.4f}",
    textposition="outside"
)

fig.show()

# %%
# =========================================== #
# 16. ENTRENAMIENTO FINAL CON TODOS LOS DATOS #
# =========================================== #

final_model = Pipeline([

    ("preprocessing", preprocessor),
    ("model", RandomForestClassifier(
            criterion=random_search.best_params_[
                "model__criterion"
            ],

            n_estimators=random_search.best_params_[
                "model__n_estimators"
            ],

            max_depth=random_search.best_params_[
                "model__max_depth"
            ],

            min_samples_split=random_search.best_params_[
                "model__min_samples_split"
            ],

            min_samples_leaf=random_search.best_params_[
                "model__min_samples_leaf"
            ],

            max_features=random_search.best_params_[
                "model__max_features"
            ],

            bootstrap=True,

            class_weight=random_search.best_params_[
                "model__class_weight"
            ],

            oob_score=True,
            random_state=123,
            n_jobs=-1
        )
    )
])

# %%
# ======================= #
# 17. ENTRENAMIENTO FINAL #
# ======================= #

final_model.fit(X, y)

# %%
# ============= #
# 18. OOB FINAL #
# ============= #

final_oob = (
    final_model
    .named_steps["model"]
    .oob_score_
)

print("")
print("="*70)
print("OOB SCORE FINAL")
print("="*70)
print(f"OOB Final: {final_oob:.4f}")

# %% [markdown]
# ---
#
# # 🎬 **¡FIN!**
#
# ---
#
# <div style="text-align: justify; line-height: 1.5; font-size: 18px;">    </div>
